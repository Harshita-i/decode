# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from statistics import median

# %%
df=pd.read_csv(r"C:\Users\immad\Downloads\Iris1.csv")

# %%
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
sns.boxplot(x='Species',y='SepalLengthCm',data=df)
plt.show()

# %%
sns.boxplot(x='class',y='sepal width',data=df)
plt.show()

# %%
sns.boxplot(x='class',y='petal length',data=df)
plt.show()

# %%
sns.boxplot(x='class',y='sepal width',data=df)
plt.show()

# %%
sns.boxplot(x='class',y='sepal length',data=df)
plt.show()

# %%
sns.histplot(x='sepal length',data=df)
plt.show()

# %%
df.plot(kind='scatter',x='petal length',y='sepal length')
plt.grid()

# %%
sns.scatterplot(x='petal length',y='sepal length',data=df,marker='+')
# Out:
# <Axes: xlabel='petal length', ylabel='sepal length'>

# %%
sns.pairplot(df)
# Out:
# C:\Users\Hp\anaconda3\anaconda2.0\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
df1=pd.read_csv()
# Out:
#   Cell In[21], line 1
#     pd.crosstab(df.class,df.sepal width)
#                    ^
# SyntaxError: invalid syntax

# %%
import seaborn as sns
import matplotlib.pyplot as plt

features = ['SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm']

for col in features:
    sns.boxplot(x='Species', y=col, data=df)
    plt.title(f"Boxplot of {col} by Species")
    plt.show()
